# %% [markdown]
# ## Practice
# **Завдання:**
# Створіть одновимірний масив із 15 випадкових цілих чисел від -10 до 10.
#
# -   Виведіть масив.
# -   За допомогою булевої індексації виберіть тільки додатні елементи.
# -   За допомогою булевої індексації виберіть тільки парні елементи.
# -   Виведіть обидва результати на екран.

# %%
import numpy as np
rng = np.random.default_rng()
array = rng.integers(-10, 10, size=15)
print(array)
# Out:
# [ 2 -9  4  8 -7  0  7  0  7 -9 -6 -2  2  6 -5]

# %%
print(f"An array with additional elements: {array[array > 0]}")
print(f"An array with even elements: {array[array % 2 == 0]}")
# Out:
# An array with additional elements: [2 4 8 7 7 2 6]
# An array with even elements: [ 2  4  8  0  0 -6 -2  2  6]
