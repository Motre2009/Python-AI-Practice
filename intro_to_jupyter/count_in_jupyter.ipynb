# %% [markdown]
# # The result:
# ## Sum: 22
# ## Difference: 8
# ## Multiple: 105
# ## Divide: 2.142857142857143

# %%
a = 15

# %%
b = 7

# %%
sumOfAB = a + b

# %%
difference = a - b

# %%
print('Sum:', sumOfAB)
# Out:
# Sum: 22

# %%
print('Difference:', difference)
# Out:
# Difference: 8

# %%
multiple = a * b

# %%
print('Multiple:', multiple)
# Out:
# Multiple: 105

# %%
divide = a / b

# %%
print('Divide:', divide)
# Out:
# Divide: 2.142857142857143
